# %% [markdown]
# # WNBA pbpstats Retrieval Bundle
#
# This notebook is the companion inspection layer for the generic pbpstats job runner.
#
# - minimum seasons: 2025, 2024, 2023
# - retrieve Regular Season and Playoffs when supported
# - keep `season_type` on every row
# - use the discovery job first so downstream on/off and shot jobs have team and player ids
# - use `preset="roster_value"` for the full workflow or `preset="totals"` / `preset="on_off"` / `preset="shot_pace"` for a family-specific smoke run

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / "scripts").exists() and (ROOT.parent / "scripts").exists():
    ROOT = ROOT.parent
SCRIPTS_DIR = ROOT / "scripts"
if str(SCRIPTS_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPTS_DIR))

import pbpstats_job_runner as runner

print("Loaded:", runner.__file__)

# %%
bundle_path = ROOT / "configs" / "pbpstats" / "jobs" / "wnba_roster_value_bundle.json"
registry_path = ROOT / "configs" / "pbpstats" / "endpoint_registry.json"
output_root = ROOT / "data" / "pbpstats_jobs"

print(bundle_path)
print(registry_path)
print(output_root)

# %%
summary = runner.run_bundle(
    bundle_path=bundle_path,
    registry_path=registry_path,
    output_root=output_root,
    preset="roster_value",
)

summary

# %%
print(summary["bundle_id"])
print(summary["records"])
print(summary["output_root"])
summary["jobs"]
